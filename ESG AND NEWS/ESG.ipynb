# %% [markdown]
# **USA**

# %%
import pandas as pd
import os
from datetime import datetime, timedelta
import random  # placeholder for demo; replace with real ESG fetching code

# --------- CONFIG -------------
COMPANIES = {
    "AAPL": "Apple",
    "MSFT": "Microsoft",
    "AMZN": "Amazon",
    "TSLA": "Tesla",
    "GOOGL": "Google",
    "S&P500": "S&P 500"
}

START_DATE = datetime(2019, 1, 1)
END_DATE   = datetime(2024, 12, 31)
save_path  = '/content/esg_scores_2019_2024_daily.csv'  # Save path for Google Colab
# ------------------------------

def fetch_esg_score(company, date):
    """
    Replace this with real scraping or API call.
    Currently generates a random ESG score for demo purposes.
    """
    return round(random.uniform(40, 80), 2)

# Initialize the list to collect all records
records = []

# Loop through each date from 2019 to 2024 and get ESG scores for each company
current = START_DATE
while current <= END_DATE:
    record = {"date": current.strftime("%Y-%m-%d")}
    for ticker, company in COMPANIES.items():
        score = fetch_esg_score(company, current)
        record[ticker] = score  # Add ESG score as a column for each company
    records.append(record)
    current += timedelta(days=1)

# Convert the list of records into a DataFrame
df = pd.DataFrame(records)

# Save the DataFrame to a CSV file
df.to_csv(save_path, index=False)

print(f"✅ Finished. Saved {len(df)} rows to:\n{save_path}")
# Out:
# ✅ Finished. Saved 2192 rows to:
# /content/esg_scores_2019_2024_daily.csv

# %%
from google.colab import files
files.download('/content/esg_scores_2019_2024_daily.csv')

# %% [markdown]
# **UK**

# %%
import pandas as pd
import os
from datetime import datetime, timedelta
import random  # placeholder for demo; replace with real ESG fetching code

# --------- CONFIG -------------
COMPANIES = {
    "FTSE 100": "FTSE 100",
    "AstraZeneca PLC": "AstraZeneca PLC",
    "HSBC Holdings PLC": "HSBC Holdings PLC",
    "Linde PLC": "Linde PLC",
    "Shell PLC": "Shell PLC",
    "Unilever PLC": "Unilever PLC"
}

START_DATE = datetime(2019, 1, 1)
END_DATE   = datetime(2024, 12, 31)
save_path  = '/content/esg_scores_2019_2024_daily.csv'  # Save path for Google Colab
# ------------------------------

def fetch_esg_score(company, date):
    """
    Replace this with real scraping or API call.
    Currently generates a random ESG score for demo purposes.
    """
    return round(random.uniform(40, 80), 2)

# Initialize the list to collect all records
records = []

# Loop through each date from 2019 to 2024 and get ESG scores for each company
current = START_DATE
while current <= END_DATE:
    record = {"date": current.strftime("%Y-%m-%d")}
    for company_name in COMPANIES:
        score = fetch_esg_score(company_name, current)
        record[company_name] = score  # Add ESG score as a column for each company
    records.append(record)
    current += timedelta(days=1)

# Convert the list of records into a DataFrame
df = pd.DataFrame(records)

# Save the DataFrame to a CSV file
df.to_csv(save_path, index=False)

print(f"✅ Finished. Saved {len(df)} rows to:\n{save_path}")
# Out:
# ✅ Finished. Saved 2192 rows to:
# /content/esg_scores_2019_2024_daily.csv

# %%
from google.colab import files
files.download('/content/esg_scores_2019_2024_daily.csv')

# %% [markdown]
# ***JAPAN***

# %%
import pandas as pd
import os
from datetime import datetime, timedelta
import random  # placeholder for demo; replace with real ESG fetching code

# --------- CONFIG -------------
COMPANIES = {
    "Nikkei 225": "Nikkei 225",
    "Toyota Motor Corporation": "Toyota Motor Corporation",
    "Mitsubishi UFJ Financial Group": "Mitsubishi UFJ Financial Group",
    "Sony Group Corporation": "Sony Group Corporation",
    "Hitachi Ltd.": "Hitachi Ltd.",
    "Nintendo Co., Ltd.": "Nintendo Co., Ltd."
}

START_DATE = datetime(2019, 1, 1)
END_DATE   = datetime(2024, 12, 31)
save_path  = '/content/esg_scores_2019_2024_daily_nikkei.csv'  # Save path for Google Colab
# ------------------------------

def fetch_esg_score(company, date):
    """
    Replace this with real scraping or API call.
    Currently generates a random ESG score for demo purposes.
    """
    return round(random.uniform(40, 80), 2)

# Initialize the list to collect all records
records = []

# Loop through each date from 2019 to 2024 and get ESG scores for each company
current = START_DATE
while current <= END_DATE:
    record = {"date": current.strftime("%Y-%m-%d")}
    for company_name in COMPANIES:
        score = fetch_esg_score(company_name, current)
        record[company_name] = score  # Add ESG score as a column for each company
    records.append(record)
    current += timedelta(days=1)

# Convert the list of records into a DataFrame
df = pd.DataFrame(records)

# Save the DataFrame to a CSV file
df.to_csv(save_path, index=False)

print(f"✅ Finished. Saved {len(df)} rows to:\n{save_path}")
# Out:
# ✅ Finished. Saved 2192 rows to:
# /content/esg_scores_2019_2024_daily_nikkei.csv

# %%
from google.colab import files
files.download('/content/esg_scores_2019_2024_daily_nikkei.csv')
